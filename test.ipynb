# %%
import pandas as pd
import json
pd.set_option('display.max_columns', 40)

# %%
with open('response.json') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['validation', 'dataset'])

# %%
df = pd.DataFrame(data['dataset'])

# %%
df.tail()
# Out:
#      pfCode    yr  period periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  \
# 9483     H5  2020    2020       2020          2       0       1  Import
# 9484     H5  2020    2020       2020          2       0       2  Export
# 9485     H5  2020    2020       2020          2       0       1  Import
# 9486     H5  2020    2020       2020          2       0       2  Export
# 9487     H5  2020    2020       2020          2       0       1  Import
#
#       rtCode   rtTitle rt3ISO  ptCode     ptTitle pt3ISO ptCode2 ptTitle2  \
# 9483     170  Colombia    COL     858     Uruguay    URY    None
# 9484     170  Colombia    COL     858     Uruguay    URY    None
# 9485     170  Colombia    COL     862   Venezuela    VEN    None
# 9486     170  Colombia    COL     862   Venezuela    VEN    None
# 9487     170  Colombia    COL     899  Areas, nes   None    None
#
#      pt3ISO2 cstCode cstDesc motCode motDesc cmdCode  \
# 9483                                              99
# ...
